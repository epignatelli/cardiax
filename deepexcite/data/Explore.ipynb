# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import random
import h5py
import math
import matplotlib.pyplot as plt
import jax
import jax.numpy as np
import fk
from IPython.display import Video
from IPython.display import HTML

# %%
root = "/media/ep119/DATADRIVE3/epignatelli/deepexcite/train_dev_set/"

# %%
name = "three_points_params6.hdf5"

# %%
path = root + name

# %%
interval = 5  #ms

with h5py.File(path, "r") as file:
    states = file["states"][::interval, 2]
    print(file["states"].shape)
    print(states.shape)
# Out:
# (2000, 3, 1200, 1200)
# (400, 1200, 1200)

# %%
# to dimensional
V = fk.convert.u_to_V(states)
video = fk.plot.animate(V,
                        times=range(0, len(states) * interval, interval),
                        vmin=-85, vmax=15)
# Out:
# <div id='00152767-287a-40f6-8d82-cf9cc234c87e'></div>

# %%
video.save(name[:-5] + ".mp4")
# Out:
# Rendering 400

# %%
Video(name[:-5] + ".mp4")
# Out:
# <video src="three_points_params6.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
Video("spiral_params5.mp4")
# Out:
# <video src="spiral_params5.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from datasets import ConcatSequence
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-832b29705a08> in <module>
# ----> 1 from datasets import ConcatSequence
#
# ModuleNotFoundError: No module named 'datasets'

# %%
import torch

# %%
x = torch.randn(3, 2, 3, 64, 64)
x[:, :, :, :32, :32] = 0.

# %%
import matplotlib.pyplot as plt
x_flip = torch.flip(x, dims=(-1, ))
plt.imshow(x[0, 0, 0])
plt.show()
plt.imshow(x_flip[0, 0, 0])
plt.show()

# %%
torch.randint(low=-2, high=0, size=(1, )).item()
# Out:
# -1
